# %% [markdown]
# <a href="https://colab.research.google.com/github/gvijaygvk/Python-Basic-07-12-2023/blob/master/Day_02/Py4DS_01_Data_Types%2C_Variables%2C_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Python for Data Science

# %% [markdown]
# #Data Types

# %% [markdown]
# ##Numbers

# %% [markdown]
# ###Integer

# %%
-2
# Out:
# -2

# %%
type(-2)
# Out:
# int

# %% [markdown]
# ### Float

# %%
5.05546
# Out:
# 5.05546

# %%
type(-5.054545)
# Out:
# float

# %% [markdown]
# ##String

# %%
'This i a string'
# Out:
# 'This i a string'

# %%
"This is also a string 2454 !@!@"
# Out:
# 'This is also a string 2454 !@!@'

# %%
type('"This is also a string 2454 !@!@"')
# Out:
# str

# %%
type("Hi")
# Out:
# str

# %%
"'I'm good"
# Out:
# "'I'm good"

# %%
'He said "Hello"'
# Out:
# 'He said "Hello"'

# %% [markdown]
# ##Boolean

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
2==2
# Out:
# True

# %%
"25"
# Out:
# '25'

# %%
int("25")
# Out:
# 25

# %%
float(True)
# Out:
# 1.0

# %%
str(25.8)
# Out:
# '25.8'

# %%
"25"+"25"
# Out:
# '2525'

# %% [markdown]
# ## Other Data Types

# %% [markdown]
# ### Advance Datatypes
# * Tuples
# * Lists
# * Dictionaries
# * Sets

# %% [markdown]
# ### Other Data Types
# * None
# * Complex
# * Bytes
# * Bytearray
# * frozenset

# %% [markdown]
# #***Variables / Identifier***
#
# ---

# %% [markdown]
# ##Variable Assignment

# %%
x=2
y=5
x*y
# Out:
# 10

# %% [markdown]
# ## Rules for Identifier
# * Can contain 0-9, a-z, A-Z and underscore
# * Cannot start with a digit
# * Length is unlimited
# * Case is significant
# * No keywords

# %% [markdown]
# # ***Operators***
#
# ---

# %% [markdown]
# ##Assignment operator (=)

# %%
a = 10
b = 5.6
a*b
# Out:
# 56.0

# %%
a,b = 10, 5.6
a*b
# Out:
# 56.0

# %%
a=b=c=10
a*b*c
# Out:
# 1000

# %%
#swap variables
a=5
b=7
a,b=b,a
a,b
# Out:
# (7, 5)

# %% [markdown]
# ##Arithmetic Operators

# %% [markdown]
# \+ Addition
#
# \- Subtraction
#
# \* Multiplication
#
# \* * Exponentiation
#
# \/ Division
#
# \// Integer Division
#
# \% Modulus

# %%
1+2

# %%
2-1

# %%
3*8

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
5%2
# Out:
# 1

# %%
2**3
# Out:
# 8

# %%
(2+3)*(8-2)
# Out:
# 24

# %% [markdown]
# The order is PEMDAS: Parentheses, Exponents, Multiplication, and Division (from left to right), Addition and Subtraction (from left to right).

# %% [markdown]
# ##Relational Operators (Comparison)
# < Less than
#
# \> Greater than
#
# <= Less than or equal to
#
# \>= Greater than or equal to
#
# \=\= Equal to
#
# != Not equal to

# %%
1 > 2
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
1 >= 1
# Out:
# True

# %%
1 <= 4
# Out:
# True

# %%
1 == 1
# Out:
# True

# %%
'hi' != 'bye'
# Out:
# True

# %% [markdown]
# ## Logic Operators
#
# and
#
# or
#
# not

# %%
(1 > 2) and (2 < 3)
# Out:
# False

# %%
(1 > 2) or (2 < 3)
# Out:
# True

# %%
(1 == 2) or (2 == 3) or (4 == 4)
# Out:
# True

# %%
not(1>2)
# Out:
# True
